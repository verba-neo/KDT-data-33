# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError
from bs4 import BeautifulSoup

html = urlopen('https://pythonscraping.com/pages/page1.html')

bs = BeautifulSoup(html.read(), 'html.parser')
bs.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
try:
    [1, 2, 3][3]
    html = urlopen('https://pythonscraping.com/pages/error.html')
    
# 모든 에러가 발생하면 아래 블럭 실행
except:
    print('Error')
# Out:
# Error

# %%
try:
    [1, 2, 3][3]
    html = urlopen('https://pythonscraping.com/pages/error.html')
    
# 모든 에러가 발생하면 아래 블럭 실행
except:
    print('Error')
# Out:
# Error

# %%
try:
    html = urlopen('https://pythonscraping.com/pages/error.html')    

# HTTPError가 발생하면 아래 블럭 실행
except HTTPError as e:
    print(e)
except URLError as e:
    print(e)

print('done')
# Out:
# HTTP Error 404: Not Found
# done

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://ko.wikipedia.org/wiki/%EC%83%88%ED%95%B4_%EC%B2%AB%EB%82%A0')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.findAll('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #bodyContent
# /wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EB%8C%80%EB%AC%B8
# /wiki/%ED%8A%B9%EC%88%98:%EC%B5%9C%EA%B7%BC%EB%B0%94%EB%80%9C
# /wiki/%ED%8F%AC%ED%84%B8:%EC%9A%94%EC%A6%98_%ED%99%94%EC%A0%9C
# /wiki/%ED%8A%B9%EC%88%98:%EC%9E%84%EC%9D%98%EB%AC%B8%EC%84%9C
# //donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_ko.wikipedia.org&uselang=ko
# /wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EC%82%AC%EB%9E%91%EB%B0%A9
# /wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EC%82%AC%EC%9A%A9%EC%9E%90_%EB%AA%A8%EC%9E%84
# /wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EC%9A%94%EC%B2%AD
# /wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EB%8F%84%EC%9B%80%EB%A7%90
# /wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EC%A0%95%EC%B1%85%EA%B3%BC_%EC%A7%80%EC%B9%A8
# /wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EC%A7%88%EB%AC%B8%EB%B0%A9
# #p-lang-btn
# /wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EB%8C%80%EB%AC%B8
# ...

# %%
# Naver API

# %%
import requests

CLIENT_ID = 'aLB0DzVqwTwiwrT9UwH6'
CLIENT_SECRET = '_sII395Q0f'

URL = 'https://openapi.naver.com/v1/search/shop.json?query=한우'

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET
}

requests.get(URL, headers=headers).json()
# Out:
# {'lastBuildDate': 'Fri, 29 Dec 2023 11:38:31 +0900',
#  'total': 530641,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '++1 마장동 <b>한우</b> 선물세트 투뿔 등심 소고기 선물 구이용 세트',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=84483282437',
#    'image': 'https://shopping-phinf.pstatic.net/main_8448328/84483282437.11.jpg',
#    'lprice': '109000',
#    'hprice': '',
#    'mallName': '예담우',
#    'productId': '84483282437',
#    'productType': '2',
#    'brand': '예담우',
#    'maker': '',
#    'category1': '식품',
#    'category2': '축산물',
#    'category3': '쇠고기',
#    'category4': '한우'},
#   {'title': '투뿔 숙성<b>한우</b> 등심 안심 갈비살 부채살 골라담기 구이용 모듬',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=83145710069',
#    'image': 'https://shopping-phinf.pstatic.net/main_8314571/83145710069.5.jpg',
#    'lprice': '29900',
#    'hprice': '',
#    'mallName': '화려한우',
#    'productId': '83145710069',
#    'productType': '2',
#    'brand': '화려한우',
#    'maker': '',
# ...
